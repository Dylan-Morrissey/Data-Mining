# %% [markdown]
# # P02 - Feature Engineering - Churn

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set(style="whitegrid")
sns.set_context("notebook")

# %%
from IPython.display import Markdown, display

OUT = "output"
import os
os.makedirs(OUT, exist_ok=True)

# %%
display_fraction = lambda n,d: (n/d*100, n, d)

# %% [markdown]
# ## Load and Prepare the Data
#
# I have made a slight change of naming convention which will simply code below - and also avoid mistakes in lab sessions when I rerun cells out of order to demo parts of the code.   Rather than using __df__ to store the full dataset I will use __df_all__, and use __df__ as an alias for various dataset as needed - see [Feature Engineering](#Feature_Engineering). So will try to follow naming convention:
#
#  * __df__ alias for various datasets (trwated link a tmp variable, more later).
#  * __df_all__ full dataset after loading and prepped (columns renamed, value recoded).
#  * __df_model__ dataset with target and a subset of the original attributes that may appear in model or be used to construct other attributes.
#  * __df_train__ dataset
#  * __df_test__ dataset

# %%
df_all = pd.read_csv("src/churn.csv")

message = (" * Data set consists of %d cases (rows) with %s attributes (cols) and a single target."  
% (df_all.shape[0], df_all.shape[1]-1))
Markdown(message)
# Out:
#  * Data set consists of 3333 cases (rows) with 20 attributes (cols) and a single target.

# %%
df_all.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# Get list of columns, some name contain spaces, or other unsuitable characters, which need to be removed.

# %%
names = df_all.columns.tolist()
print("Original columns names:\n", names)
# Out:
# Original columns names:
#  ['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan", 'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge', 'CustServ Calls', 'Churn?']

# %%
CORRECTIONS = {" ":"_", "'":"", "?":"", "CustServ":"Cust_Serv"}

def fixName(s):
    for a,b in CORRECTIONS.items():
        s = s.replace(a,b)
    return s

mapping = {c:fixName(c) for c in names}

# %%
df_all.rename(columns=mapping, inplace=True)

# %%
df_all.head()
# Out:
#   State  Account_Length  Area_Code     Phone Intl_Plan VMail_Plan  \
# 0    KS             128        415  382-4657        no        yes
# 1    OH             107        415  371-7191        no        yes
# 2    NJ             137        415  358-1921        no         no
# 3    OH              84        408  375-9999       yes         no
# 4    OK              75        415  330-6626       yes         no
#
#    VMail_Message  Day_Mins  Day_Calls  Day_Charge  ...  Eve_Calls  Eve_Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night_Mins  Night_Calls  Night_Charge  Intl_Mins  Intl_Calls  Intl_Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    Cust_Serv_Calls   Churn
# 0                1  False.
# 1                1  False.
# 2                0  False.
# 3                2  False.
# 4                3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# Replace the binary target and the two binary features with numerical values.

# %%
df_all.Intl_Plan = df_all.Intl_Plan.map( {"yes":1, "no":0} )
df_all.VMail_Plan = df_all.VMail_Plan.apply( lambda x: int(x=='yes') )
df_all.Churn = df_all.Churn.apply( lambda x: int(x=="True.") )

# %%
df_all.head()
# Out:
#   State  Account_Length  Area_Code     Phone  Intl_Plan  VMail_Plan  \
# 0    KS             128        415  382-4657          0           1
# 1    OH             107        415  371-7191          0           1
# 2    NJ             137        415  358-1921          0           0
# 3    OH              84        408  375-9999          1           0
# 4    OK              75        415  330-6626          1           0
#
#    VMail_Message  Day_Mins  Day_Calls  Day_Charge  ...  Eve_Calls  Eve_Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night_Mins  Night_Calls  Night_Charge  Intl_Mins  Intl_Calls  Intl_Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    Cust_Serv_Calls  Churn
# 0                1      0
# 1                1      0
# 2                0      0
# 3                2      0
# 4                3      0
#
# [5 rows x 21 columns]

# %%
# save data for comparision with R model 
if False:
    from sklearn.model_selection import train_test_split
    df_train, df_test = train_test_split(df_model, stratify=df_model[target], test_size=.25, random_state=666)
    open ("data/churn_train.csv", "wt").write(df_train.to_csv())
    open ("data/churn_test.csv", "wt").write(df_test.to_csv())

# %% [markdown]
# ## Pre-Processing Data

# %%
target = "Churn"
attributes = df_all.columns.tolist()
attributes.remove(target) 
attributes = [a for a in attributes if a not in ["State", "Phone", "Area_Code"]]
attributes = [a for a in attributes if a.split("_")[-1] != "Charge"]

df_model = df_all.loc[:, attributes + [target]]

# %%
attributes_initial = df_model.columns.tolist()
attributes_initial.remove(target)

# %% [markdown]
# ### Side Note - Down-Sampling
#
# When a dataset is imbalanced, one can generate a balanced dataset by taking a sample of the larger set.

# %%
df_balanced_down_sampling = pd.concat ([
    df_all[df_all.Churn==0].sample(n=sum(df_all.Churn==1), random_state=42),
    df_all[df_all.Churn==1]])

# %% [markdown]
# ### Train-Test Split

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_model, stratify=df_model[target], test_size=.25, random_state=42)

# %% [markdown]
# ## Feature_Engineering
#
# Features engineering and selection decision is carried out on __df_train__ ONLY, but resulting operations should be applied to both __df_train__ and __df_test__. The simplest way to do this (without repeating code) is to apply operations to __df_model__ and repeat the train/test split USING THE SAME SEED.

# %% [markdown]
# ### New Feature - Cranky Triskaidekaphobias
#
# Would a feature indicating customers who complain and avoid the number 13 be useful in predicting Churn?

# %%
my_query = df_model.query('Cust_Serv_Calls>0 & Day_Calls!=13 & Eve_Calls!=13 & Night_Calls!=13 & Intl_Calls!=13')
my_query.head()
# Out:
#    Account_Length  Intl_Plan  VMail_Plan  VMail_Message  Day_Mins  Day_Calls  \
# 0             128          0           1             25     265.1        110
# 1             107          0           1             26     161.6        123
# 3              84          1           0              0     299.4         71
# 4              75          1           0              0     166.7        113
# 6             121          0           1             24     218.2         88
#
#    Eve_Mins  Eve_Calls  Night_Mins  Night_Calls  Intl_Mins  Intl_Calls  \
# 0     197.4         99       244.7           91       10.0           3
# 1     195.5        103       254.4          103       13.7           3
# 3      61.9         88       196.9           89        6.6           7
# 4     148.3        122       186.9          121       10.1           3
# 6     348.5        108       212.6          118        7.5           7
#
#    Cust_Serv_Calls  Churn
# 0                1      0
# 1                1      0
# 3                2      0
# 4                3      0
# 6                3      0

# %%
df_model["Cranky_Triskaidekaphobias"] = df_model.apply (lambda row: (row.Cust_Serv_Calls>0 
            and row.Day_Calls!=13 and row.Eve_Calls!=13 
            and row.Night_Calls!=13 and row.Intl_Calls!=13), axis=1)

# %% [markdown]
# ### New Feature - Total_time

# %%
Total_Time = df_all['Day_Mins'] + df_all['Eve_Mins'] + df_all['Night_Mins'] + df_all['Intl_Mins']
Total_Time.head()
# Out:
# 0    717.2
# 1    625.2
# 2    539.4
# 3    564.8
# 4    512.0
# dtype: float64

# %%
df_model["Total_Time"] = Total_Time

# %% [markdown]
# ### New Feature - total_calls

# %%
total_calls = df_model['Day_Calls'] + df_model['Eve_Calls'] + df_model['Night_Calls'] + df_model['Intl_Calls']
total_calls.head()
# Out:
# 0    303
# 1    332
# 2    333
# 3    255
# 4    359
# dtype: int64

# %%
df_model["Total_Calls"] = total_calls

# %% [markdown]
# ### New Feature - Average call time

# %%
df_model["Average_Call_Time"] = Total_Time/total_calls
df_model.head()
# Out:
#    Account_Length  Intl_Plan  VMail_Plan  VMail_Message  Day_Mins  Day_Calls  \
# 0             128          0           1             25     265.1        110
# 1             107          0           1             26     161.6        123
# 2             137          0           0              0     243.4        114
# 3              84          1           0              0     299.4         71
# 4              75          1           0              0     166.7        113
#
#    Eve_Mins  Eve_Calls  Night_Mins  Night_Calls  Intl_Mins  Intl_Calls  \
# 0     197.4         99       244.7           91       10.0           3
# 1     195.5        103       254.4          103       13.7           3
# 2     121.2        110       162.6          104       12.2           5
# 3      61.9         88       196.9           89        6.6           7
# 4     148.3        122       186.9          121       10.1           3
#
#    Cust_Serv_Calls  Churn  Cranky_Triskaidekaphobias  Total_Time  Total_Calls  \
# 0                1      0                       True       717.2          303
# 1                1      0                       True       625.2          332
# 2                0      0                      False       539.4          333
# 3                2      0                       True       564.8          255
# 4                3      0                       True       512.0          359
#
#    Average_Call_Time
# 0           2.366997
# 1           1.883133
# 2           1.619820
# 3           2.214902
# 4           1.426184

# %% [markdown]
# ### New Feature - Unhappy Customer

# %%
my_query = df_model.query('Cust_Serv_Calls>3')
my_query.head()
# Out:
#     Account_Length  Intl_Plan  VMail_Plan  VMail_Message  Day_Mins  Day_Calls  \
# 10              65          0           0              0     129.1        137
# 14              62          0           0              0     120.7         70
# 15             161          0           0              0     332.9         67
# 21              77          0           0              0      62.4         89
# 48             119          0           0              0     159.1        114
#
#     Eve_Mins  Eve_Calls  Night_Mins  Night_Calls  Intl_Mins  Intl_Calls  \
# 10     228.5         83       208.8          111       12.7           6
# 14     307.2         76       203.0           99       13.1           6
# 15     317.8         97       160.6          128        5.4           9
# 21     169.9        121       209.6           64        5.7           6
# 48     231.3        117       143.2           91        8.8           3
#
#     Cust_Serv_Calls  Churn  Cranky_Triskaidekaphobias  Total_Time  \
# 10                4      1                       True       579.1
# 14                4      0                       True       644.0
# 15                4      1                       True       816.7
# 21                5      1                       True       447.6
# 48                5      1                       True       542.4
#
#     Total_Calls  Average_Call_Time
# 10          337           1.718398
# 14          251           2.565737
# 15          301           2.713289
# 21          280           1.598571
# 48          325           1.668923

# %%
df_model["Unhappy_Customer"] = df_model.apply (lambda row: (row.Cust_Serv_Calls>3), axis=1)

# %% [markdown]
# ### New Feature - International Intrest

# %%
my_query = df_model.query('Intl_Plan!=0')

# %%
df_model["Intl_Intrest"] = df_model.apply (lambda row: (row.Intl_Plan!=0), axis=1)
df_model.head()
# Out:
#    Account_Length  Intl_Plan  VMail_Plan  VMail_Message  Day_Mins  Day_Calls  \
# 0             128          0           1             25     265.1        110
# 1             107          0           1             26     161.6        123
# 2             137          0           0              0     243.4        114
# 3              84          1           0              0     299.4         71
# 4              75          1           0              0     166.7        113
#
#    Eve_Mins  Eve_Calls  Night_Mins  Night_Calls  Intl_Mins  Intl_Calls  \
# 0     197.4         99       244.7           91       10.0           3
# 1     195.5        103       254.4          103       13.7           3
# 2     121.2        110       162.6          104       12.2           5
# 3      61.9         88       196.9           89        6.6           7
# 4     148.3        122       186.9          121       10.1           3
#
#    Cust_Serv_Calls  Churn  Cranky_Triskaidekaphobias  Total_Time  Total_Calls  \
# 0                1      0                       True       717.2          303
# 1                1      0                       True       625.2          332
# 2                0      0                      False       539.4          333
# 3                2      0                       True       564.8          255
# 4                3      0                       True       512.0          359
#
#    Average_Call_Time  Unhappy_Customer  Intl_Intrest
# 0           2.366997             False         False
# 1           1.883133             False         False
# 2           1.619820             False         False
# 3           2.214902             False          True
# 4           1.426184             False          True

# %% [markdown]
# ### New Feature - Non_Answer

# %%
my_query = df_model.query('VMail_Plan!=1')

# %%
df_model["Non_Answer"] = df_model.apply (lambda row: (row.VMail_Plan!=1), axis=1)
df_model["Non_Answer"].head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Non_Answer, dtype: bool

# %% [markdown]
# ### New Feature - High_Day

# %%
total_charge = df_all['Day_Charge'] + df_all['Eve_Charge'] + df_all['Night_Charge'] + df_all['Intl_Charge']
total_charge.head()
# Out:
# 0    75.56
# 1    59.24
# 2    62.29
# 3    66.80
# 4    52.09
# dtype: float64

# %%
df_model["Total_Charge"] = total_charge

# %% [markdown]
# ## New Feature - Average Charge

# %%
df_model["Average_Charge"] = df_model['Total_Charge'] / df_model['Total_Time']
df_model["Average_Charge"].head()
# Out:
# 0    0.105354
# 1    0.094754
# 2    0.115480
# 3    0.118272
# 4    0.101738
# Name: Average_Charge, dtype: float64

# %%
df_model["Non_Answer"] = df_model.apply (lambda row: (row.VMail_Message!=0), axis=1)
df_model["Non_Answer"].head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Non_Answer, dtype: bool

# %%
df_model["Calls_Aroad"] = df_model.apply (lambda row: (row.Intl_Calls>2), axis=1)
df_model.head()
# Out:
#    Account_Length  Intl_Plan  VMail_Plan  VMail_Message  Day_Mins  Day_Calls  \
# 0             128          0           1             25     265.1        110
# 1             107          0           1             26     161.6        123
# 2             137          0           0              0     243.4        114
# 3              84          1           0              0     299.4         71
# 4              75          1           0              0     166.7        113
#
#    Eve_Mins  Eve_Calls  Night_Mins  Night_Calls  ...  \
# 0     197.4         99       244.7           91  ...
# 1     195.5        103       254.4          103  ...
# 2     121.2        110       162.6          104  ...
# 3      61.9         88       196.9           89  ...
# 4     148.3        122       186.9          121  ...
#
#    Cranky_Triskaidekaphobias  Total_Time  Total_Calls  Average_Call_Time  \
# 0                       True       717.2          303           2.366997
# 1                       True       625.2          332           1.883133
# 2                      False       539.4          333           1.619820
# 3                       True       564.8          255           2.214902
# 4                       True       512.0          359           1.426184
#
#    Unhappy_Customer  Intl_Intrest  Non_Answer  Total_Charge  Average_Charge  \
# 0             False         False        True         75.56        0.105354
# 1             False         False        True         59.24        0.094754
# 2             False         False       False         62.29        0.115480
# 3             False          True       False         66.80        0.118272
# 4             False          True       False         52.09        0.101738
#
#    Calls_Aroad
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Model Training

# %%
print (df_model.columns.values)
# Out:
# ['Account_Length' 'Intl_Plan' 'VMail_Plan' 'VMail_Message' 'Day_Mins'
#  'Day_Calls' 'Eve_Mins' 'Eve_Calls' 'Night_Mins' 'Night_Calls' 'Intl_Mins'
#  'Intl_Calls' 'Cust_Serv_Calls' 'Churn' 'Cranky_Triskaidekaphobias'
#  'Total_Time' 'Total_Calls' 'Average_Call_Time' 'Unhappy_Customer'
#  'Intl_Intrest' 'Non_Answer' 'Total_Charge' 'Average_Charge' 'Calls_Aroad']

# %% [markdown]
# ### Train-Test Split
#
# REPEAT train/test split from above so that both data subsets have the modified feature set.

# %%
df_train, df_test = train_test_split(df_model, stratify=df_model[target], test_size=.25, random_state=42)
attributes = df_model.columns.tolist()
attributes.remove(target)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(df_train.loc[:,attributes].astype(float))
y_train = df_train.Churn.values

X_test = scaler.transform(df_test.loc[:,attributes].astype(float))
y_test = df_test.Churn.values

# %% [markdown]
# ### Evaluation
#
# We spoke about the AUC metric last week. This week we will focus on recall - it is easier and probably more relevant in this case and we want to focus on identifying as many Churn customers as possible.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score, roc_auc_score

models = []

# %% [markdown]
# ### Training - First Iteration
#
# Just fix a few of our standard classifiers, using default/semi-sane parameters.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
models.append( {"name":"LogisticRegression", "ref": LogisticRegression(solver="lbfgs")} )

# %% [markdown]
# #### Support Vector Machines

# %%
from sklearn.svm import SVC
models.append( {"name":"SVC", "ref":SVC(gamma="scale")} )

# %% [markdown]
# #### Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
models.append( {"name":"DT (prunned=4)", "ref":DecisionTreeClassifier(criterion='entropy', max_depth=4)} )

# %%
for model in models:
    
    crossval_scores = cross_val_score(model["ref"], X_train, y_train, scoring='recall', cv=5)
    print ("\nModel %s" % model["name"])
    print ("\tCV scores %s" % crossval_scores)
    print ("\tmean=%.3f std=%.3f" % (crossval_scores.mean(), crossval_scores.std()))
# Out:
# Model LogisticRegression
# 	CV scores [0.2739726  0.2739726  0.33333333 0.31944444 0.26388889]
# 	mean=0.293 std=0.028
#
# Model SVC
# 	CV scores [0.75342466 0.71232877 0.55555556 0.625      0.68055556]
# 	mean=0.665 std=0.069
#
# Model DT (prunned=4)
# 	CV scores [0.83561644 0.65753425 0.72222222 0.77777778 0.73611111]
# 	mean=0.746 std=0.059

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

model = models[2]["ref"]

rfecv = RFECV(estimator=model, step=1, cv=StratifiedKFold(2), scoring="recall")
rfecv.fit(X_train, y_train)
print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 5

# %%
# list of features selected
attributes_selected = np.array(attributes)[rfecv.support_].tolist()
attributes_selected
# Out:
# ['VMail_Message',
#  'Unhappy_Customer',
#  'Intl_Intrest',
#  'Total_Charge',
#  'Calls_Aroad']

# %% [markdown]
# ### Training - After Feature Selection

# %%
df_model = df_model.loc[:, attributes_selected + [target]]
display(df_model.head())

# train-test split
df_train, df_test = train_test_split(df_model, stratify=df_model[target], test_size=.25, random_state=42)
attributes = df_model.columns.tolist()
attributes.remove(target)

# normalise 
X_train = scaler.fit_transform(df_train.loc[:,attributes].astype(float))
y_train = df_train.Churn.values
X_test = scaler.transform(df_test.loc[:,attributes].astype(float))
y_test = df_test.Churn.values

for model in models:
    
    crossval_scores = cross_val_score(model["ref"], X_train, y_train, scoring='recall', cv=5)
    print ("\nModel %s" % model["name"])
    print ("\tCV scores %s" % crossval_scores)
    print ("\tmean=%.3f std=%.3f" % (crossval_scores.mean(), crossval_scores.std()))
# Out:
#    VMail_Message  Unhappy_Customer  Intl_Intrest  Total_Charge  Calls_Aroad  \
# 0             25             False         False         75.56         True
# 1             26             False         False         59.24         True
# 2              0             False         False         62.29         True
# 3              0             False          True         66.80         True
# 4              0             False          True         52.09         True
#
#    Churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# Model LogisticRegression
# 	CV scores [0.21917808 0.19178082 0.19444444 0.23611111 0.19444444]
# 	mean=0.207 std=0.018
#
# Model SVC
# 	CV scores [0.79452055 0.7260274  0.65277778 0.72222222 0.69444444]
# 	mean=0.718 std=0.046
#
# Model DT (prunned=4)
# 	CV scores [0.83561644 0.7260274  0.72222222 0.77777778 0.73611111]
# 	mean=0.760 std=0.043
